# %% [markdown]
# # Step 3-2 ARIMAX

# %% [markdown]
# For ARIMA-X, the features we should add are exogenous variables.
#
# Not all the features from the previous step, Feature Selection, can be used. (such like cumulative_co2)
#
# * ARIMA-X already handles temporal dynamics, exclude `time lags`
#
# * Any `cumulative` features will be excluded since they are not stationary -> monotonically increase
#
# The selected features are:
#
# `primary_energy_consumption`, `gdp`, `population`, `electricity_demand`, `oil_production`,
#
# `nuclear_consumption`, `wind_consumption`, `biofuel_consumption`, `energy_per_gdp`
#
# **workflow of ARIMAX**:
#
# select exogenous variables -> check stationarity of exogenous variables -> difference exogenous variables to match ARIMA's parameter d ->
#
# train ARIMAX on train data -> fit once -> forecast test period

# %% [markdown]
# ### Necessary imports

# %%
# Necessary imports 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller

import warnings
import os

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Config

# %%
TARGET_VARIABLES = 'co2'
SELECTED_COUNTRIES = ['United States', 'China', 'India']
TEST_SIZE = 9
save_dir = 'data/03_02_results'
os.makedirs(save_dir, exist_ok=True)

# ARIMA optimal orders
ARIMA_ORDERS = {
    'United States': (0, 1, 0),
    'China': (0, 2, 0),
    'India': (1, 1, 1)
}

# Exogenous variables
EXOG_VARIABLES = [
    'gdp',
    'primary_energy_consumption',
    #'electricity_demand', # this variable is excluded since the available data for China and India are from year 2000 
    'population',
    'oil_production',
    'nuclear_consumption',
    'wind_consumption',
    'biofuel_consumption',
    'energy_per_gdp'
]

# %% [markdown]
# ### Data load

# %%
def load_data(save_dir='data'):
    data_files = {
        'all_data_df': os.path.join(save_dir, 'all_data_df.csv'),
        'g20_lag_df': os.path.join(save_dir, 'g20_lag_df.csv'),
        'lag_three_sel_1969_df': os.path.join(save_dir, 'lag_three_sel_1969_df.csv')
    }

    dfs = {}
    for name, filepath in data_files.items():
        if os.path.exists(filepath):
            dfs[name] = pd.read_csv(filepath)
            print(f"Loaded {name}: {dfs[name].shape}")
        else:
            print(f"{filepath} not found")
    
    return dfs

# %%
data = load_data()
all_data_df = data['all_data_df']
g20_lag_df = data['g20_lag_df']
g20_lag_1969_df = g20_lag_df[g20_lag_df['year'] >= 1969].copy()
g20_lag_1969_df = g20_lag_1969_df[g20_lag_1969_df['year'] < 2023]
lag_three_sel_1969_df = data['lag_three_sel_1969_df']
# Out:
# Loaded all_data_df: (55529, 200)
# Loaded g20_lag_df: (3744, 992)
# Loaded lag_three_sel_1969_df: (162, 992)

# %%
# Checking if exogenous varialbes in the dataset
for feature in EXOG_VARIABLES:
    if feature in lag_three_sel_1969_df.columns:
        print(f"    {feature} in the dataset")
    else:
        print(f"    {feature} not in the dataset")
# Out:
#     gdp in the dataset
#     primary_energy_consumption in the dataset
#     population in the dataset
#     oil_production in the dataset
#     nuclear_consumption in the dataset
#     wind_consumption in the dataset
#     biofuel_consumption in the dataset
#     energy_per_gdp in the dataset

# %% [markdown]
# ### Data preparation

# %%
# train_test_split
def tts_by_year(df, test_size=9):
    train_data = {}
    test_data = {}

    for country in df['country'].unique():
        country_data = df[df['country'] == country].sort_values('year')

        split_idx = len(country_data) - test_size
        train_data[country] = country_data.iloc[:split_idx]
        test_data[country] = country_data.iloc[split_idx:]

    train_df = pd.concat(train_data.values(), ignore_index=True)
    test_df = pd.concat(test_data.values(), ignore_index=True)

    return train_df, test_df

# %%
# Keep necessary columns
cols_to_keep = ['country', 'year', TARGET_VARIABLES] + EXOG_VARIABLES
selected_data = lag_three_sel_1969_df[cols_to_keep].copy()

selected_data = selected_data.dropna()

print(f"Data shape: {selected_data.shape}")
print(f"Year: {selected_data['year'].min()} - {selected_data['year'].max()}")
# Out:
# Data shape: (162, 11)
# Year: 1969 - 2022

# %%
# TTS
train_df, test_df = tts_by_year(selected_data, TEST_SIZE)

print(f"Train shape: {train_df.shape}")
print(f"Test shape: {test_df.shape}")
print(f"Train year: {train_df['year'].min()} - {train_df['year'].max()}")
print(f"Test year: {test_df['year'].min()} - {test_df['year'].max()}")
# Out:
# Train shape: (135, 11)
# Test shape: (27, 11)
# Train year: 1969 - 2013
# Test year: 2014 - 2022

# %% [markdown]
# ### Helper

# %%
def mase(y_actual, y_pred, period=1):
    mae_forecast = mean_absolute_error(y_actual, y_pred)

    naive_forecast = y_actual[:-period] if period > 0 else y_actual[:-1]
    actual_for_naive = y_actual[period:] if period > 0 else y_actual[1:]

    if len(naive_forecast) == 0:
        return np.nan
    
    mae_naive = mean_absolute_error(actual_for_naive, naive_forecast)

    if mae_naive == 0:
        return 0 if mae_forecast == 0 else np.inf
    
    return mae_forecast / mae_naive

# %%
def adf_test(series, name='Series', country=''):
    """
    p_value < 0.05: Rejct Null hypothesis -> stationary
    """
    # pd -> dropna
    if isinstance(series, pd.Series):
        updated_series = series.dropna()
    # np -> remove nan
    else:
        updated_series = series[~np.isnan(series)]

    result = adfuller(updated_series, autolag='AIC')

    adf_stat = result[0]
    p_value = result[1]
    critical_values = result[4]

    print(f"\n{name} ({country}):")
    print(f"ADF Statistics: {adf_stat:.4f}")
    print(f"p-value: {p_value:.4f}")

    if p_value < 0.05:
        is_stationary = True
    else:
        is_stationary = False

    print(f"Critical Value:")
    for k, v in critical_values.items():
        print(f"    {k}: {v:.4f}")

    return {
        'adf_stat': adf_stat,
        'p_value': p_value,
        'critical_values': critical_values,
        'is_stationary': is_stationary
    }

# %%
def check_stationarity(df, features, country):
    print(f"\nFor {country.upper()}")

    results = {}

    for feature in features:
        feature_data = df[feature].values
        result = adf_test(feature_data, name=feature, country=country)
        results[feature] = result

    return results

# %%
def difference_series(series, order):
    diff_series = series.copy()
    for i in range(order):
        diff_series = diff_series.diff().dropna()
    return diff_series

# %% [markdown]
# ### Check Stationarity for each country

# %%
stationarity_results = {}

for country in SELECTED_COUNTRIES:
    country_train = train_df[train_df['country'] == country].sort_values('year')

    print(f"\nOriginal features for {country.upper()}")
    original_results = check_stationarity(country_train, EXOG_VARIABLES, country)

    d = ARIMA_ORDERS[country][1]

    if d > 0:
        differenced_results = {}
        for feature in EXOG_VARIABLES:
            feature_data = country_train[feature].values

            diff_data = feature_data.copy()
            for i in range(d):
                diff_data = np.diff(diff_data)

            result = adf_test(diff_data, name=f"{feature} d={d}", country=country)
            differenced_results[feature] = result

        stationarity_results[country] = {
            'original': original_results,
            'differenced': differenced_results,
            'd': d
        }
    else:
        stationarity_results[country] = {
            'original': original_results,
            'd': d
        }
# Out:
# Original features for UNITED STATES
#
# For UNITED STATES
#
# gdp (United States):
# ADF Statistics: 0.3374
# p-value: 0.9790
# Critical Value:
#     1%: -3.5925
#     5%: -2.9315
#     10%: -2.6041
#
# primary_energy_consumption (United States):
# ADF Statistics: -1.6422
# p-value: 0.4611
# Critical Value:
#     1%: -3.5886
#     5%: -2.9299
#     10%: -2.6032
#
# population (United States):
# ADF Statistics: 5.3776
# p-value: 1.0000
# Critical Value:
#     1%: -3.5966
#     5%: -2.9333
#     10%: -2.6050
#
# oil_production (United States):
# ADF Statistics: -2.0120
# p-value: 0.2813
# Critical Value:
#     1%: -3.6010
#     5%: -2.9351
#     10%: -2.6060
#
# nuclear_consumption (United States):
# ADF Statistics: -2.3033
# p-value: 0.1709
# Critical Value:
#     1%: -3.5925
#     5%: -2.9315
#     10%: -2.6041
#
# wind_consumption (United States):
# ADF Statistics: 1.7432
# p-value: 0.9982
# Critical Value:
#     1%: -3.6267
#     5%: -2.9460
#     10%: -2.6117
#
# biofuel_consumption (United States):
# ADF Statistics: 2.2941
# p-value: 0.9990
# Critical Value:
#     1%: -3.6155
#     5%: -2.9413
#     10%: -2.6092
#
# energy_per_gdp (United States):
# ADF Statistics: -0.8981
# p-value: 0.7886
# Critical Value:
#     1%: -3.5886
#     5%: -2.9299
#     10%: -2.6032
#
# gdp d=1 (United States):
# ADF Statistics: -4.4699
# p-value: 0.0002
# Critical Value:
#     1%: -3.5925
#     5%: -2.9315
#     10%: -2.6041
#
# primary_energy_consumption d=1 (United States):
# ADF Statistics: -5.4121
# p-value: 0.0000
# Critical Value:
#     1%: -3.5925
#     5%: -2.9315
#     10%: -2.6041
#
# population d=1 (United States):
# ADF Statistics: -0.8223
# p-value: 0.8125
# Critical Value:
#     1%: -3.6209
#     5%: -2.9435
#     10%: -2.6104
#
# oil_production d=1 (United States):
# ADF Statistics: -2.1335
# p-value: 0.2313
# Critical Value:
#     1%: -3.5925
#     5%: -2.9315
#     10%: -2.6041
#
# nuclear_consumption d=1 (United States):
# ADF Statistics: -4.7661
# p-value: 0.0001
# Critical Value:
#     1%: -3.5925
#     5%: -2.9315
#     10%: -2.6041
#
# wind_consumption d=1 (United States):
# ADF Statistics: 1.4971
# p-value: 0.9975
# Critical Value:
#     1%: -3.6327
#     5%: -2.9485
#     10%: -2.6130
#
# biofuel_consumption d=1 (United States):
# ADF Statistics: -1.8215
# p-value: 0.3698
# Critical Value:
#     1%: -3.6155
#     5%: -2.9413
#     10%: -2.6092
#
# energy_per_gdp d=1 (United States):
# ADF Statistics: -2.5328
# p-value: 0.1077
# Critical Value:
#     1%: -3.6010
#     5%: -2.9351
#     10%: -2.6060
#
# Original features for CHINA
#
# For CHINA
#
# gdp (China):
# ADF Statistics: 14.5504
# p-value: 1.0000
# Critical Value:
#     1%: -3.5886
#     5%: -2.9299
#     10%: -2.6032
#
# primary_energy_consumption (China):
# ADF Statistics: 1.7316
# p-value: 0.9982
# Critical Value:
#     1%: -3.5966
#     5%: -2.9333
#     10%: -2.6050
#
# population (China):
# ADF Statistics: -3.3961
# p-value: 0.0111
# Critical Value:
#     1%: -3.6267
#     5%: -2.9460
#     10%: -2.6117
#
# oil_production (China):
# ADF Statistics: -2.0974
# p-value: 0.2456
# Critical Value:
#     1%: -3.6056
#     5%: -2.9371
#     10%: -2.6070
#
# nuclear_consumption (China):
# ADF Statistics: 4.7315
# p-value: 1.0000
# Critical Value:
#     1%: -3.5886
#     5%: -2.9299
#     10%: -2.6032
#
# wind_consumption (China):
# ADF Statistics: 2.8844
# p-value: 1.0000
# Critical Value:
#     1%: -3.6104
#     5%: -2.9391
#     10%: -2.6081
#
# biofuel_consumption (China):
# ADF Statistics: -8.5294
# p-value: 0.0000
# Critical Value:
#     1%: -3.6392
#     5%: -2.9512
#     10%: -2.6144
#
# energy_per_gdp (China):
# ADF Statistics: -2.9443
# p-value: 0.0404
# Critical Value:
#     1%: -3.5925
#     5%: -2.9315
#     10%: -2.6041
#
# gdp d=2 (China):
# ADF Statistics: -4.7264
# p-value: 0.0001
# Critical Value:
#     1%: -3.6104
#     5%: -2.9391
#     10%: -2.6081
#
# primary_energy_consumption d=2 (China):
# ADF Statistics: -5.5480
# p-value: 0.0000
# Critical Value:
#     1%: -3.5966
#     5%: -2.9333
#     10%: -2.6050
#
# population d=2 (China):
# ADF Statistics: -2.5841
# p-value: 0.0963
# Critical Value:
#     1%: -3.6461
#     5%: -2.9541
#     10%: -2.6160
#
# oil_production d=2 (China):
# ADF Statistics: -3.9345
# p-value: 0.0018
# Critical Value:
#     1%: -3.6327
#     5%: -2.9485
#     10%: -2.6130
#
# nuclear_consumption d=2 (China):
# ADF Statistics: -5.7556
# p-value: 0.0000
# Critical Value:
#     1%: -3.6327
#     5%: -2.9485
#     10%: -2.6130
#
# wind_consumption d=2 (China):
# ADF Statistics: 3.7246
# p-value: 1.0000
# Critical Value:
#     1%: -3.6535
#     5%: -2.9572
#     10%: -2.6176
#
# biofuel_consumption d=2 (China):
# ADF Statistics: -6.7793
# p-value: 0.0000
# Critical Value:
#     1%: -3.6535
#     5%: -2.9572
#     10%: -2.6176
#
# energy_per_gdp d=2 (China):
# ADF Statistics: -6.1584
# p-value: 0.0000
# Critical Value:
#     1%: -3.5966
#     5%: -2.9333
#     10%: -2.6050
#
# Original features for INDIA
#
# For INDIA
#
# gdp (India):
# ADF Statistics: 16.9224
# p-value: 1.0000
# Critical Value:
#     1%: -3.5886
#     5%: -2.9299
#     10%: -2.6032
#
# primary_energy_consumption (India):
# ADF Statistics: 9.5255
# p-value: 1.0000
# Critical Value:
#     1%: -3.5886
#     5%: -2.9299
#     10%: -2.6032
#
# population (India):
# ADF Statistics: -4.7363
# p-value: 0.0001
# Critical Value:
#     1%: -3.6327
#     5%: -2.9485
#     10%: -2.6130
#
# oil_production (India):
# ADF Statistics: -1.2802
# p-value: 0.6382
# Critical Value:
#     1%: -3.5925
#     5%: -2.9315
#     10%: -2.6041
#
# nuclear_consumption (India):
# ADF Statistics: 2.6105
# p-value: 0.9991
# Critical Value:
#     1%: -3.6392
#     5%: -2.9512
#     10%: -2.6144
#
# wind_consumption (India):
# ADF Statistics: 0.8672
# p-value: 0.9926
# Critical Value:
#     1%: -3.6392
#     5%: -2.9512
#     10%: -2.6144
#
# biofuel_consumption (India):
# ADF Statistics: 0.4012
# p-value: 0.9815
# Critical Value:
#     1%: -3.6392
#     5%: -2.9512
#     10%: -2.6144
#
# energy_per_gdp (India):
# ADF Statistics: -1.2997
# p-value: 0.6293
# Critical Value:
#     1%: -3.6155
#     5%: -2.9413
#     10%: -2.6092
#
# gdp d=1 (India):
# ADF Statistics: 0.3772
# p-value: 0.9806
# Critical Value:
#     1%: -3.6010
#     5%: -2.9351
#     10%: -2.6060
#
# primary_energy_consumption d=1 (India):
# ADF Statistics: -1.3131
# p-value: 0.6232
# Critical Value:
#     1%: -3.5966
#     5%: -2.9333
#     10%: -2.6050
#
# population d=1 (India):
# ADF Statistics: -1.3102
# p-value: 0.6245
# Critical Value:
#     1%: -3.6392
#     5%: -2.9512
#     10%: -2.6144
#
# oil_production d=1 (India):
# ADF Statistics: -4.8590
# p-value: 0.0000
# Critical Value:
#     1%: -3.5925
#     5%: -2.9315
#     10%: -2.6041
#
# nuclear_consumption d=1 (India):
# ADF Statistics: -0.8587
# p-value: 0.8013
# Critical Value:
#     1%: -3.6461
#     5%: -2.9541
#     10%: -2.6160
#
# wind_consumption d=1 (India):
# ADF Statistics: 7.2428
# p-value: 1.0000
# Critical Value:
#     1%: -3.6461
#     5%: -2.9541
#     10%: -2.6160
#
# biofuel_consumption d=1 (India):
# ADF Statistics: 1.6295
# p-value: 0.9979
# Critical Value:
#     1%: -3.6392
#     5%: -2.9512
#     10%: -2.6144
#
# energy_per_gdp d=1 (India):
# ADF Statistics: -1.5062
# p-value: 0.5305
# Critical Value:
#     1%: -3.6155
#     5%: -2.9413
#     10%: -2.6092

# %%
for country in SELECTED_COUNTRIES:
    d = stationarity_results[country]['d']
    print(f"\n{country.upper()} - ARIMA order{ARIMA_ORDERS[country]}")

    if d > 0:
        print(f"\nBefore differencing:")
        for feature, result in stationarity_results[country]['original'].items():
            stat = "Stationary" if result['is_stationary'] else "Not Stationary"
            print(f"    {feature}: {stat}, p-value = {result['p_value']:.4f}")

        print(f"\nDifferenced features d = {d}:")
        for feature, result in stationarity_results[country]['differenced'].items():
            stat = "Stationary" if result['is_stationary'] else "Not Stationary"
            print(f"    {feature}: {stat}, p-value = {result['p_value']:.4f}")
    else:
        print(f" No differencing needed:")
        for feature, result in stationarity_results[country]['original'].items():
            stat = "Stationary" if result['is_stationary'] else "Not Stationary"
            print(f"    {feature}: {stat}, p-value = {result['p_value']:.4f}")
# Out:
# UNITED STATES - ARIMA order(0, 1, 0)
#
# Before differencing:
#     gdp: Not Stationary, p-value = 0.9790
#     primary_energy_consumption: Not Stationary, p-value = 0.4611
#     population: Not Stationary, p-value = 1.0000
#     oil_production: Not Stationary, p-value = 0.2813
#     nuclear_consumption: Not Stationary, p-value = 0.1709
#     wind_consumption: Not Stationary, p-value = 0.9982
#     biofuel_consumption: Not Stationary, p-value = 0.9990
#     energy_per_gdp: Not Stationary, p-value = 0.7886
#
# Differenced features d = 1:
#     gdp: Stationary, p-value = 0.0002
#     primary_energy_consumption: Stationary, p-value = 0.0000
#     population: Not Stationary, p-value = 0.8125
#     oil_production: Not Stationary, p-value = 0.2313
#     nuclear_consumption: Stationary, p-value = 0.0001
#     wind_consumption: Not Stationary, p-value = 0.9975
#     biofuel_consumption: Not Stationary, p-value = 0.3698
#     energy_per_gdp: Not Stationary, p-value = 0.1077
#
# CHINA - ARIMA order(0, 2, 0)
#
# Before differencing:
#     gdp: Not Stationary, p-value = 1.0000
#     primary_energy_consumption: Not Stationary, p-value = 0.9982
#     population: Stationary, p-value = 0.0111
#     oil_production: Not Stationary, p-value = 0.2456
#     nuclear_consumption: Not Stationary, p-value = 1.0000
#     wind_consumption: Not Stationary, p-value = 1.0000
#     biofuel_consumption: Stationary, p-value = 0.0000
#     energy_per_gdp: Stationary, p-value = 0.0404
#
# Differenced features d = 2:
#     gdp: Stationary, p-value = 0.0001
#     primary_energy_consumption: Stationary, p-value = 0.0000
#     population: Not Stationary, p-value = 0.0963
#     oil_production: Stationary, p-value = 0.0018
#     nuclear_consumption: Stationary, p-value = 0.0000
#     wind_consumption: Not Stationary, p-value = 1.0000
#     biofuel_consumption: Stationary, p-value = 0.0000
#     energy_per_gdp: Stationary, p-value = 0.0000
#
# INDIA - ARIMA order(1, 1, 1)
#
# Before differencing:
#     gdp: Not Stationary, p-value = 1.0000
#     primary_energy_consumption: Not Stationary, p-value = 1.0000
#     population: Stationary, p-value = 0.0001
#     oil_production: Not Stationary, p-value = 0.6382
#     nuclear_consumption: Not Stationary, p-value = 0.9991
#     wind_consumption: Not Stationary, p-value = 0.9926
#     biofuel_consumption: Not Stationary, p-value = 0.9815
#     energy_per_gdp: Not Stationary, p-value = 0.6293
#
# Differenced features d = 1:
#     gdp: Not Stationary, p-value = 0.9806
#     primary_energy_consumption: Not Stationary, p-value = 0.6232
#     population: Not Stationary, p-value = 0.6245
#     oil_production: Stationary, p-value = 0.0000
#     nuclear_consumption: Not Stationary, p-value = 0.8013
#     wind_consumption: Not Stationary, p-value = 1.0000
#     biofuel_consumption: Not Stationary, p-value = 0.9979
#     energy_per_gdp: Not Stationary, p-value = 0.5305

# %% [markdown]
# We can see only `gdp`, `primary_energy_consumption`, `nuclear_consumption` are stationary with d=1 for the US.
#
# Those features in the US and, addtionally, `oil_production`, `energy_per_gdp`, `biofuel_consumption` are stationary with d=2 for China.
#
# None of the features were stationary with the optimal ARIMA differencing order for India. For India, only ARIMA is usable.
