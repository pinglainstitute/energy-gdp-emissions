# %% [markdown]
# # Step 3-1 Feature Selection

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import os
import warnings

warnings.filterwarnings("ignore")

# %%
TARGET_VARIABLES = 'co2'
MAX_LAGS = 4
COLS_TO_EXCLUDE = ['co2', 'country', 'year', 'iso_code']

SELECTED_COUNTRIES = ['United States', 'China', 'India']
G7_COUNTRIES = ['United States', 'China', 'India', 'Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom']
G20_COUNTRIES = [
    'United States', 'China', 'Japan', 'Germany', 
    'United Kingdom', 'France', 'Italy', 'Canada',
    'Brazil', 'Russia', 'India', 'Australia', 
    'Mexico', 'Indonesia', 'Turkey', 'Saudi Arabia',
    'South Africa', 'Argentina', 'South Korea'
]

# %%
def load_data(save_dir='data'):
    data_files = {
        'all_data_df': os.path.join(save_dir, 'all_data_df.csv'),
        'g20_lag_df': os.path.join(save_dir, 'g20_lag_df.csv'),
        'lag_three_sel_1969_df': os.path.join(save_dir, 'lag_three_sel_1969_df.csv')
    }

    dfs = {}
    for name, filepath in data_files.items():
        if os.path.exists(filepath):
            dfs[name] = pd.read_csv(filepath)
            print(f"Loaded {name}: {dfs[name].shape}")
        else:
            print(f"{filepath} not found")
    
    return dfs

# %%
data = load_data()
all_data_df = data['all_data_df']
g20_lag_df = data['g20_lag_df']
g20_lag_1969_df = g20_lag_df[g20_lag_df['year'] >= 1969].copy()
g20_lag_1969_df = g20_lag_1969_df[g20_lag_1969_df['year'] < 2023]
lag_three_sel_1969_df = data['lag_three_sel_1969_df']
# Out:
# Loaded all_data_df: (55529, 200)
# Loaded g20_lag_df: (3744, 992)
# Loaded lag_three_sel_1969_df: (162, 992)

# %%
def find_feature_cols(df, exclude_cols):
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    feature_cols = [col for col in numeric_cols if col not in exclude_cols]
    return feature_cols

# %%
feature_cols = find_feature_cols(lag_three_sel_1969_df, COLS_TO_EXCLUDE)
g20_feature_cols = find_feature_cols(g20_lag_1969_df, COLS_TO_EXCLUDE)

# %%
def calculate_pct_change(df, features, max_lags=MAX_LAGS):
    df_copy = df.copy()
    df_copy = df_copy.sort_values(['country', 'year']).reset_index(drop=True)
    pct_change_cols = []

    for feature in features:
        if feature not in df_copy.columns:
            continue

        # Pct change on current values
        lag1_col = f"{feature}_lag1"
        if lag1_col in df_copy.columns:
            df_copy[f"{feature}_pct_change"] = ((df_copy[feature] - df_copy[lag1_col]) / df_copy[lag1_col] * 100)
            pct_change_cols.append(f"{feature}_pct_change")

        # Pct change on lagged values
        for lag in range(1, max_lags):
            lag_col = f"{feature}_lag{lag}"
            prev_lag_col = f"{feature}_lag{lag+1}"
            
            if lag_col in df_copy.columns and prev_lag_col in df_copy.columns:
                df_copy[f"{lag_col}_pct_change"] = ((df_copy[lag_col] - df_copy[prev_lag_col]) / df_copy[prev_lag_col] * 100)
                pct_change_cols.append(f"{lag_col}_pct_change")

        # Lag4 for the first row = 0, then shift lag3_pct by country
        last_lag_col = f"{feature}_lag{max_lags}"
        lag3_pct_col = f"{feature}_lag{max_lags-1}_pct_change"

        if last_lag_col in df_copy.columns and lag3_pct_col in df_copy.columns:
            df_copy[f"{last_lag_col}_pct_change"] = df_copy.groupby('country')[lag3_pct_col].shift(1).fillna(0)
            pct_change_cols.append(f"{last_lag_col}_pct_change")
            
        df_copy = df_copy.replace([np.inf, -np.inf], np.nan)
    
    return df_copy, pct_change_cols

# %%
df_pct_change, pct_change_cols = calculate_pct_change(lag_three_sel_1969_df, feature_cols, MAX_LAGS)
g20_df_pct_change, g20_pct_change_cols = calculate_pct_change(g20_lag_1969_df, g20_feature_cols, MAX_LAGS)

df_selected = df_pct_change[df_pct_change['country'].isin(SELECTED_COUNTRIES)].copy()
g7_df_selected = g20_df_pct_change[g20_df_pct_change['country'].isin(G7_COUNTRIES)].copy()
g20_df_selected = g20_df_pct_change[g20_df_pct_change['country'].isin(G20_COUNTRIES)].copy()

# %%
def calculate_correlations(df, target, pct_change_cols, countries):
    country_corr = {}

    for country in countries:
        country_data = df[df['country'] == country].copy()

        corr_cols = [target] + [col for col in pct_change_cols if col in country_data.columns]

        if target in country_data.columns and len(corr_cols) > 1:
            # Calculate correlations
            correlations = country_data[corr_cols].corr()[target].drop(target)
            correlations = correlations.dropna().sort_values(ascending=False)
            country_corr[country] = correlations
        else:
            print(f"Error of {country}")

    return country_corr

# %%
country_correlations = calculate_correlations(df_selected, TARGET_VARIABLES, pct_change_cols, SELECTED_COUNTRIES)
g7_correlations = calculate_correlations(g7_df_selected, TARGET_VARIABLES, g20_pct_change_cols, G7_COUNTRIES)
g20_correlations = calculate_correlations(g20_df_selected, TARGET_VARIABLES, g20_pct_change_cols, G20_COUNTRIES)

# %%
# Summary for 3 countries
for country, corr in country_correlations.items():
    print(f"{country}: {len(corr)} features")
# Out:
# United States: 985 features
# China: 970 features
# India: 945 features

# %%
# Summary for 3 countries + G7
for country, corr in g7_correlations.items():
    print(f"{country}: {len(corr)} features")
# Out:
# United States: 985 features
# China: 970 features
# India: 945 features
# Canada: 967 features
# France: 985 features
# Germany: 985 features
# Italy: 977 features
# Japan: 955 features
# United Kingdom: 970 features

# %%
# Summary for G20
for country, corr in g20_correlations.items():
    print(f"{country}: {len(corr)} features")
# Out:
# United States: 985 features
# China: 970 features
# Japan: 955 features
# Germany: 985 features
# United Kingdom: 970 features
# France: 985 features
# Italy: 977 features
# Canada: 967 features
# Brazil: 970 features
# Russia: 970 features
# India: 945 features
# Australia: 920 features
# Mexico: 945 features
# Indonesia: 915 features
# Turkey: 940 features
# Saudi Arabia: 715 features
# South Africa: 940 features
# Argentina: 940 features
# South Korea: 910 features

# %%
save_dir = 'data/03_01_results'
os.makedirs(save_dir, exist_ok=True)

md_filepath = os.path.join(save_dir, 'correlation_by_3_countries.md')
with open(md_filepath, 'w') as f:
    f.write("# Correlation Analysis with Percentage Change Normalised Features for 3 Countries\n\n")
    f.write("---\n\n")
    
    for country in SELECTED_COUNTRIES:
        f.write(f"## {country}\n\n")
        f.write(f"### Correlation with {TARGET_VARIABLES}\n\n")
        
        corr_df = country_correlations[country].to_frame(name='Correlation')
        corr_df.index.name = 'Feature'
        f.write(corr_df.to_markdown())
        f.write("\n\n---\n\n")

# %%
md_filepath = os.path.join(save_dir, 'correlation_by_g7_and_3.md')
with open(md_filepath, 'w') as f:
    f.write("# Correlation Analysis with Percentage Change Normalised Features for G7 + 3 Countries\n\n")
    f.write("---\n\n")
    
    for country in G7_COUNTRIES:
        f.write(f"## {country}\n\n")
        f.write(f"### Correlation with {TARGET_VARIABLES}\n\n")
        
        corr_df = g7_correlations[country].to_frame(name='Correlation')
        corr_df.index.name = 'Feature'
        f.write(corr_df.to_markdown())
        f.write("\n\n---\n\n")

# %%
md_filepath = os.path.join(save_dir, 'correlation_by_g20_countries.md')
with open(md_filepath, 'w') as f:
    f.write("# Correlation Analysis with Percentage Change Normalised Features for G20 Countries\n\n")
    f.write("---\n\n")
    
    for country in G20_COUNTRIES:
        f.write(f"## {country}\n\n")
        f.write(f"### Correlation with {TARGET_VARIABLES}\n\n")
        
        corr_df = g20_correlations[country].to_frame(name='Correlation')
        corr_df.index.name = 'Feature'
        f.write(corr_df.to_markdown())
        f.write("\n\n---\n\n")

# %%
def create_overall_ranking(country_correlations):
    all_features = {}
    
    for country, corr in country_correlations.items():
        for feature, value in corr.items():
            if feature not in all_features:
                all_features[feature] = {}
            all_features[feature][country] = abs(value)
    
    # Calculate mean absolute correlation
    ranking_data = []
    for feature, country_values in all_features.items():
        mean_abs_corr = np.mean(list(country_values.values()))
        ranking_data.append({
            'Feature': feature,
            'Mean_Abs_Corr': mean_abs_corr,
            'US_Corr': country_values.get('United States', np.nan),
            'China_Corr': country_values.get('China', np.nan),
            'India_Corr': country_values.get('India', np.nan)
        })
    
    ranking_df = pd.DataFrame(ranking_data)
    ranking_df = ranking_df.sort_values('Mean_Abs_Corr', ascending=False)
    
    return ranking_df

# %%
ranking_3_df = create_overall_ranking(country_correlations)
ranking_3_df.head(40)
# Out:
#                                                Feature  Mean_Abs_Corr  \
# 984                      cumulative_luc_co2_pct_change       0.780654
# 983                 cumulative_luc_co2_lag1_pct_change       0.763779
# 980                 cumulative_luc_co2_lag2_pct_change       0.745644
# 977                 cumulative_oil_co2_lag3_pct_change       0.724537
# 975                 cumulative_oil_co2_lag2_pct_change       0.717563
# 974                 cumulative_oil_co2_lag1_pct_change       0.710328
# 970                 cumulative_luc_co2_lag3_pct_change       0.708239
# 973                      cumulative_oil_co2_pct_change       0.706955
# 880                         population_lag3_pct_change       0.694447
# 762                         population_lag2_pct_change       0.654926
# 923                 cumulative_luc_co2_lag4_pct_change       0.632272
# 578                         population_lag1_pct_change       0.627533
# 0      share_global_cumulative_oil_co2_lag3_pct_change       0.627448
# 442                              population_pct_change       0.612460
# 1      share_global_cumulative_oil_co2_lag2_pct_change       0.608296
# 10   other_renewable_exc_biofuel_electricity_lag3_p...       0.600758
# 11   other_renewables_elec_per_capita_exc_biofuel_l...       0.594703
# 951                     cumulative_co2_lag3_pct_change       0.583862
# 2      share_global_cumulative_oil_co2_lag1_pct_change       0.582023
# 192                 electricity_demand_lag4_pct_change       0.570795
# 6      share_global_cumulative_oil_co2_lag4_pct_change       0.570693
# 110  share_of_temperature_change_from_ghg_lag3_pct_...       0.565675
# 3           share_global_cumulative_oil_co2_pct_change       0.564099
# 949                     cumulative_co2_lag2_pct_change       0.556597
# 927                 cumulative_oil_co2_lag4_pct_change       0.551939
# 940                     cumulative_co2_lag1_pct_change       0.550014
# 936                          cumulative_co2_pct_change       0.548011
# 978                      cumulative_gas_co2_pct_change       0.546493
# 175  share_of_temperature_change_from_ghg_lag2_pct_...       0.536333
# 12   share_global_cumulative_cement_co2_lag3_pct_ch...       0.534593
# 8       share_global_cumulative_flaring_co2_pct_change       0.533855
# 9    share_global_cumulative_flaring_co2_lag1_pct_c...       0.532692
# 901    share_global_cumulative_luc_co2_lag4_pct_change       0.532571
# 918       cumulative_co2_including_luc_lag2_pct_change       0.532193
# 65                     consumption_co2_lag4_pct_change       0.530017
# 430      electricity_demand_per_capita_lag4_pct_change       0.527826
# 102       share_global_cumulative_other_co2_pct_change       0.526225
# 979                 cumulative_gas_co2_lag1_pct_change       0.525290
# 982                 cumulative_gas_co2_lag2_pct_change       0.523441
# 4    share_global_cumulative_flaring_co2_lag3_pct_c...       0.522790
#
#       US_Corr  China_Corr  India_Corr
# 984  0.786938    0.866410    0.688616
# 983  0.741438    0.868791    0.681108
# 980  0.703326    0.868895    0.664712
# 977  0.661291    0.666847    0.845474
# 975  0.644813    0.652289    0.855587
# 974  0.632180    0.640786    0.858017
# 970  0.596091    0.872300    0.656327
# 973  0.626816    0.631062    0.862986
# 880  0.295118    0.814994    0.973229
# 762  0.174106    0.813517    0.977155
# 923  0.478330    0.821773    0.596712
# 578  0.087885    0.814280    0.980435
# 0    0.804562    0.591334    0.486447
# 442  0.034713    0.819953    0.982712
# 1    0.804163    0.571271    0.449454
# 10   0.600758         NaN         NaN
# 11   0.594703         NaN         NaN
# 951  0.545295    0.469085    0.737206
# 2    0.799610    0.561204    0.385255
# 192  0.112584    0.752961    0.846839
# 6    0.656298    0.544150    0.511632
# 110  0.228537    0.645050    0.823437
# 3    0.786874    0.553600    0.351824
# 949  0.538411    0.482149    0.649232
# 927  0.489841    0.607094    0.558881
# 940  0.526344    0.533897    0.589802
# 936  0.516656    0.590088    0.537290
# 978  0.691473    0.213591    0.734414
# 175  0.130420    0.661116    0.817463
# 12   0.593376    0.459865    0.550537
# 8    0.646699    0.397142    0.557723
# 9    0.646354    0.401810    0.549913
# 901  0.383868    0.829117    0.384726
# 918  0.442887    0.190635    0.963058
# 65   0.318736    0.597431    0.673885
# 430  0.028787    0.738072    0.816619
# 102  0.238815    0.813635         NaN
# 979  0.701676    0.232564    0.641630
# 982  0.707806    0.272353    0.590166
# 4    0.688726    0.407709    0.471936

# %%
def create_overall_g7_ranking(g7_correlations):
    all_features = {}
    
    for country, corr in g7_correlations.items():
        for feature, value in corr.items():
            if feature not in all_features:
                all_features[feature] = {}
            all_features[feature][country] = abs(value)
    
    # Calculate mean absolute correlation
    ranking_data = []
    for feature, country_values in all_features.items():
        mean_abs_corr = np.mean(list(country_values.values()))
        ranking_data.append({
            'Feature': feature,
            'Mean_Abs_Corr': mean_abs_corr,
            'US_Corr': country_values.get('United States', np.nan),
            'China_Corr': country_values.get('China', np.nan),
            'India_Corr': country_values.get('India', np.nan),
            'Canada_Corr': country_values.get('Canada', np.nan),
            'France_Corr': country_values.get('France', np.nan),
            'Germany_Corr': country_values.get('Germany', np.nan),
            'Italy_Corr': country_values.get('Italy', np.nan),
            'Japan_Corr': country_values.get('Japan', np.nan),
            'UK_Corr': country_values.get('United Kingdom', np.nan)
        })
    
    ranking_df = pd.DataFrame(ranking_data)
    ranking_df = ranking_df.sort_values('Mean_Abs_Corr', ascending=False)
    
    return ranking_df

# %%
ranking_g7_df = create_overall_g7_ranking(g7_correlations)
ranking_g7_df.head(40)
# Out:
#                                                Feature  Mean_Abs_Corr  \
# 977                 cumulative_oil_co2_lag3_pct_change       0.726445
# 975                 cumulative_oil_co2_lag2_pct_change       0.720574
# 974                 cumulative_oil_co2_lag1_pct_change       0.714839
# 951                     cumulative_co2_lag3_pct_change       0.713912
# 936                          cumulative_co2_pct_change       0.711347
# 973                      cumulative_oil_co2_pct_change       0.710347
# 949                     cumulative_co2_lag2_pct_change       0.709826
# 940                     cumulative_co2_lag1_pct_change       0.709311
# 972              cumulative_cement_co2_lag3_pct_change       0.660828
# 918       cumulative_co2_including_luc_lag2_pct_change       0.652411
# 971              cumulative_cement_co2_lag2_pct_change       0.651359
# 916       cumulative_co2_including_luc_lag1_pct_change       0.651141
# 908            cumulative_co2_including_luc_pct_change       0.647393
# 967                   cumulative_cement_co2_pct_change       0.647198
# 969              cumulative_cement_co2_lag1_pct_change       0.646906
# 911       cumulative_co2_including_luc_lag3_pct_change       0.641241
# 981                 cumulative_gas_co2_lag3_pct_change       0.622682
# 982                 cumulative_gas_co2_lag2_pct_change       0.619046
# 978                      cumulative_gas_co2_pct_change       0.618013
# 979                 cumulative_gas_co2_lag1_pct_change       0.615821
# 927                 cumulative_oil_co2_lag4_pct_change       0.614150
# 12   share_global_cumulative_cement_co2_lag3_pct_ch...       0.612462
# 17   share_global_cumulative_cement_co2_lag2_pct_ch...       0.593364
# 110  share_of_temperature_change_from_ghg_lag3_pct_...       0.591810
# 984                      cumulative_luc_co2_pct_change       0.591042
# 980                 cumulative_luc_co2_lag2_pct_change       0.590313
# 970                 cumulative_luc_co2_lag3_pct_change       0.589245
# 731  share_global_cumulative_co2_including_luc_lag1...       0.588792
# 983                 cumulative_luc_co2_lag1_pct_change       0.588590
# 711  share_global_cumulative_co2_including_luc_lag2...       0.587644
# 646  share_global_cumulative_co2_including_luc_pct_...       0.582471
# 542  share_global_cumulative_co2_including_luc_lag3...       0.581198
# 38   share_global_cumulative_cement_co2_lag1_pct_ch...       0.581087
# 749  share_global_cumulative_co2_including_luc_lag4...       0.579160
# 59       share_global_cumulative_cement_co2_pct_change       0.575650
# 164                     cumulative_coal_co2_pct_change       0.572033
# 175  share_of_temperature_change_from_ghg_lag2_pct_...       0.569482
# 0      share_global_cumulative_oil_co2_lag3_pct_change       0.565497
# 202        share_global_cumulative_coal_co2_pct_change       0.562627
# 83    share_global_cumulative_coal_co2_lag3_pct_change       0.561634
#
#       US_Corr  China_Corr  India_Corr  Canada_Corr  France_Corr  Germany_Corr  \
# 977  0.661291    0.666847    0.845474     0.872545     0.843773      0.689195
# 975  0.644813    0.652289    0.855587     0.863579     0.831349      0.683576
# 974  0.632180    0.640786    0.858017     0.853315     0.820108      0.677775
# 951  0.545295    0.469085    0.737206     0.873429     0.914750      0.912670
# 936  0.516656    0.590088    0.537290     0.870113     0.933854      0.918392
# 973  0.626816    0.631062    0.862986     0.844174     0.804631      0.675806
# 949  0.538411    0.482149    0.649232     0.878444     0.925621      0.911530
# 940  0.526344    0.533897    0.589802     0.875997     0.930305      0.910011
# 972  0.626336    0.761688    0.097306     0.869289     0.838221      0.742356
# 918  0.442887    0.190635    0.963058     0.776958     0.927897      0.919890
# 971  0.607438    0.775187    0.046597     0.853748     0.831394      0.736716
# 916  0.436253    0.158203    0.966198     0.773310     0.933620      0.918339
# 908  0.409333    0.110914    0.964939     0.771179     0.939192      0.926764
# 967  0.571376    0.880817    0.040395     0.836040     0.811459      0.713824
# 969  0.591560    0.812319    0.040792     0.840874     0.819362      0.726596
# 911  0.416560    0.182794    0.964847     0.780574     0.914803      0.921007
# 981  0.704768    0.315410    0.548004     0.913710     0.882450      0.677169
# 982  0.707806    0.272353    0.590166     0.910683     0.879341      0.649503
# 978  0.691473    0.213591    0.734414     0.901605     0.871164      0.606548
# 979  0.701676    0.232564    0.641630     0.907568     0.877513      0.623546
# 927  0.489841    0.607094    0.558881     0.710892     0.844460      0.663785
# 12   0.593376    0.459865    0.550537     0.480011     0.852326      0.821107
# 17   0.522477    0.487996    0.492619     0.456200     0.828254      0.811298
# 110  0.228537    0.645050    0.823437     0.405515     0.847069      0.806532
# 984  0.786938    0.866410    0.688616     0.804628     0.719015      0.186700
# 980  0.703326    0.868895    0.664712     0.807216     0.762925      0.209598
# 970  0.596091    0.872300    0.656327     0.818850     0.784051      0.140598
# 731  0.150745    0.416045    0.975181     0.414790     0.918099      0.889990
# 983  0.741438    0.868791    0.681108     0.803728     0.748187      0.163923
# 711  0.138472    0.428878    0.970688     0.419233     0.914321      0.889997
# 646  0.111139    0.383385    0.974977     0.387705     0.924969      0.901238
# 542  0.071404    0.404013    0.967538     0.439376     0.906617      0.894125
# 38   0.433509    0.588227    0.466623     0.472153     0.798268      0.792477
# 749  0.163879    0.414800    0.951615     0.502985     0.905930      0.900909
# 59   0.354295    0.743545    0.456376     0.507593     0.771927      0.756879
# 164  0.142628    0.467874    0.824037     0.239358     0.865119      0.913052
# 175  0.130420    0.661116    0.817463     0.318019     0.860320      0.819198
# 0    0.804562    0.591334    0.486447     0.207284     0.773261      0.583600
# 202  0.102925    0.567830    0.816564     0.274609     0.814133      0.870037
# 83   0.275553    0.398789    0.862216     0.094109     0.839382      0.861959
#
#      Italy_Corr  Japan_Corr   UK_Corr
# 977    0.504449    0.782703  0.671723
# 975    0.497797    0.776436  0.679744
# 974    0.493927    0.770049  0.687391
# 951    0.354490    0.740058  0.878226
# 936    0.350580    0.755631  0.929517
# 973    0.492111    0.767241  0.688300
# 949    0.353316    0.749533  0.900196
# 940    0.352040    0.754296  0.911110
# 972    0.439427    0.848557  0.724273
# 918    0.053658    0.703120  0.893597
# 971    0.440745    0.842788  0.727615
# 916    0.055135    0.712295  0.906912
# 908    0.059132    0.717793  0.927292
# 967    0.417839    0.821508  0.731525
# 969    0.432046    0.830824  0.727780
# 911    0.034360    0.686875  0.869352
# 981    0.273635    0.729666  0.559327
# 982    0.268467    0.735375  0.557721
# 978    0.264744    0.756079  0.522501
# 979    0.272162    0.744614  0.541118
# 927    0.375281    0.662494  0.614625
# 12     0.242166    0.818892  0.693875
# 17     0.281514    0.827616  0.632302
# 110    0.223095    0.688070  0.658985
# 984    0.061575    0.876372  0.329123
# 980    0.079892    0.863234  0.353020
# 970    0.231451    0.853319  0.350218
# 731    0.005584    0.714024  0.814672
# 983    0.078366    0.873561  0.338207
# 711    0.004874    0.701315  0.821021
# 646    0.012264    0.717667  0.828900
# 542    0.035358    0.684842  0.827511
# 38     0.295349    0.823359  0.559821
# 749    0.131203    0.569993  0.671123
# 59     0.303154    0.823465  0.463621
# 164    0.473216    0.363241  0.859769
# 175    0.222755    0.695571  0.600478
# 0      0.503202    0.746336  0.393448
# 202    0.480531    0.365666  0.771346
# 83     0.512561    0.375277  0.834863

# %%
def create_overall_g20_ranking(g20_correlations):
    all_features = {}
    
    for country, corr in g20_correlations.items():
        for feature, value in corr.items():
            if feature not in all_features:
                all_features[feature] = {}
            all_features[feature][country] = abs(value)
    
    # Calculate mean absolute correlation
    ranking_data = []
    for feature, country_values in all_features.items():
        mean_abs_corr = np.mean(list(country_values.values()))
        ranking_data.append({
            'Feature': feature,
            'Mean_Abs_Corr': mean_abs_corr,
            'US_Corr': country_values.get('United States', np.nan),
            'China_Corr': country_values.get('China', np.nan),
            'India_Corr': country_values.get('India', np.nan)
        })
    
    ranking_df = pd.DataFrame(ranking_data)
    ranking_df = ranking_df.sort_values('Mean_Abs_Corr', ascending=False)
    
    return ranking_df

# %%
ranking_g20_df = create_overall_g20_ranking(g20_correlations)
ranking_g20_df.head(40)
# Out:
#                                                Feature  Mean_Abs_Corr  \
# 973                      cumulative_oil_co2_pct_change       0.722374
# 974                 cumulative_oil_co2_lag1_pct_change       0.718888
# 951                     cumulative_co2_lag3_pct_change       0.715253
# 936                          cumulative_co2_pct_change       0.714848
# 975                 cumulative_oil_co2_lag2_pct_change       0.713767
# 972              cumulative_cement_co2_lag3_pct_change       0.712606
# 949                     cumulative_co2_lag2_pct_change       0.712479
# 940                     cumulative_co2_lag1_pct_change       0.711284
# 977                 cumulative_oil_co2_lag3_pct_change       0.707767
# 971              cumulative_cement_co2_lag2_pct_change       0.706890
# 969              cumulative_cement_co2_lag1_pct_change       0.702076
# 967                   cumulative_cement_co2_pct_change       0.700437
# 880                         population_lag3_pct_change       0.674070
# 12   share_global_cumulative_cement_co2_lag3_pct_ch...       0.659463
# 17   share_global_cumulative_cement_co2_lag2_pct_ch...       0.657804
# 38   share_global_cumulative_cement_co2_lag1_pct_ch...       0.655850
# 762                         population_lag2_pct_change       0.655058
# 59       share_global_cumulative_cement_co2_pct_change       0.654085
# 578                         population_lag1_pct_change       0.636862
# 442                              population_pct_change       0.633849
# 73   share_global_cumulative_cement_co2_lag4_pct_ch...       0.621347
# 913              cumulative_cement_co2_lag4_pct_change       0.610312
# 927                 cumulative_oil_co2_lag4_pct_change       0.602236
# 62              share_global_cumulative_co2_pct_change       0.599104
# 57         share_global_cumulative_co2_lag1_pct_change       0.593291
# 0      share_global_cumulative_oil_co2_lag3_pct_change       0.591631
# 54         share_global_cumulative_co2_lag2_pct_change       0.589445
# 46         share_global_cumulative_co2_lag3_pct_change       0.582915
# 1      share_global_cumulative_oil_co2_lag2_pct_change       0.574451
# 979                 cumulative_gas_co2_lag1_pct_change       0.569454
# 978                      cumulative_gas_co2_pct_change       0.569445
# 982                 cumulative_gas_co2_lag2_pct_change       0.568295
# 981                 cumulative_gas_co2_lag3_pct_change       0.566808
# 646  share_global_cumulative_co2_including_luc_pct_...       0.565363
# 731  share_global_cumulative_co2_including_luc_lag1...       0.562965
# 2      share_global_cumulative_oil_co2_lag1_pct_change       0.557002
# 6      share_global_cumulative_oil_co2_lag4_pct_change       0.556974
# 711  share_global_cumulative_co2_including_luc_lag2...       0.553502
# 3           share_global_cumulative_oil_co2_pct_change       0.550831
# 908            cumulative_co2_including_luc_pct_change       0.547064
#
#       US_Corr  China_Corr  India_Corr
# 973  0.626816    0.631062    0.862986
# 974  0.632180    0.640786    0.858017
# 951  0.545295    0.469085    0.737206
# 936  0.516656    0.590088    0.537290
# 975  0.644813    0.652289    0.855587
# 972  0.626336    0.761688    0.097306
# 949  0.538411    0.482149    0.649232
# 940  0.526344    0.533897    0.589802
# 977  0.661291    0.666847    0.845474
# 971  0.607438    0.775187    0.046597
# 969  0.591560    0.812319    0.040792
# 967  0.571376    0.880817    0.040395
# 880  0.295118    0.814994    0.973229
# 12   0.593376    0.459865    0.550537
# 17   0.522477    0.487996    0.492619
# 38   0.433509    0.588227    0.466623
# 762  0.174106    0.813517    0.977155
# 59   0.354295    0.743545    0.456376
# 578  0.087885    0.814280    0.980435
# 442  0.034713    0.819953    0.982712
# 73   0.306905    0.313397    0.573039
# 913  0.424254    0.485218    0.189719
# 927  0.489841    0.607094    0.558881
# 62   0.333674    0.325673    0.724085
# 57   0.359511    0.212188    0.745181
# 0    0.804562    0.591334    0.486447
# 54   0.368063    0.121443    0.768994
# 46   0.398288    0.096177    0.800950
# 1    0.804163    0.571271    0.449454
# 979  0.701676    0.232564    0.641630
# 978  0.691473    0.213591    0.734414
# 982  0.707806    0.272353    0.590166
# 981  0.704768    0.315410    0.548004
# 646  0.111139    0.383385    0.974977
# 731  0.150745    0.416045    0.975181
# 2    0.799610    0.561204    0.385255
# 6    0.656298    0.544150    0.511632
# 711  0.138472    0.428878    0.970688
# 3    0.786874    0.553600    0.351824
# 908  0.409333    0.110914    0.964939

# %%
ranking_filepath = os.path.join(save_dir, 'overall_3_countries_ranking.md')
with open(ranking_filepath, 'w') as f:
    f.write("# Overall Feature Ranking\n\n")
    f.write("Features ranked by mean absolute correlation across 3 Countries\n\n")
    f.write(ranking_3_df.to_markdown(index=False))

# %%
ranking_filepath = os.path.join(save_dir, 'overall_g7_countries_ranking.md')
with open(ranking_filepath, 'w') as f:
    f.write("# Overall Feature Ranking\n\n")
    f.write("Features ranked by mean absolute correlation across 3 Countries and G7\n\n")
    f.write(ranking_g7_df.to_markdown(index=False))

# %%
ranking_filepath = os.path.join(save_dir, 'overall_g20_countries_ranking.md')
with open(ranking_filepath, 'w') as f:
    f.write("# Overall Feature Ranking\n\n")
    f.write("Features ranked by mean absolute correlation across G20 Countries\n\n")
    f.write(ranking_g20_df.to_markdown(index=False))

# %% [markdown]
# Best 7 features from the selected 3 countries:
#
# cumulative_luc_co2, cumulative_oil_co2, population, cumulative_co2, electricity_demand, share_of_temperature_change_from_ghg, share_global_cumulative_cement_co2

# %% [markdown]
# Best 6 features from G7 + selected 3 countries:
#
# cumulative_oil_co2, cumulative_co2, cumulative_cement_co2, cumulative_co2_including_luc, cumulative_gas_co2, cumulative_luc_co2

# %% [markdown]
# Best 5 features from G20 countries:
#
# cumulative_oil_co2, cumulative_oil_co2, cumulative_cement_co2, population, cumulative_gas_co2
